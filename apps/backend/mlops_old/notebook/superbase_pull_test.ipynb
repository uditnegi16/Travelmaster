# %%
import os

# 1) Ensure we are in mlops
os.chdir(r"D:\labmentix\major\TravelGuru\apps\backend\agent_in_update")

# 2) Walk and print tree
for root, dirs, files in os.walk("."):
    level = root.count(os.sep)
    indent = "    " * level
    print(f"{indent}{os.path.basename(root)}/")
    sub_indent = "    " * (level + 1)
    for f in files:
        print(f"{sub_indent}{f}")
# Out:
# ./
#     langgraph_agents.zip
#     __init__.py
#     adk_remote_agent/
#         agent_executor.py
#         budget_and_experience_optimization_agent.py
#         __init__.py
#         __main__.py
#     adk_travel_host/
#         adk_tools.py
#         remote_agent_connection.py
#         travel_orchestrator_agent.py
#         __init__.py
#     crewai_remote_agent/
#         agent_executor.py
#         explorer_agent.py
#         __init__.py
#         __main__.py
#     langgraph_agents/
#         api.py
#         composer_agent.py
#         local_tool_router.py
#         memory.py
#         planner_agent.py
#         travel_planner_graph.py
#         __init__.py
#         prompts/
#             composer.txt
#             composer_old.txt
#             composer_old_backup.txt
#             planner.txt
#         shared/
#             debug_a2a_methods.py
#             mcp_client.py
#             schemas (1).py
#             test_mcp_client.py
#             test_send_and_poll.py
#             __init__.py
#         tools/
#             budget/
#                 helpers.py
#                 service.py
#                 __init__.py
#                 __pycache__/
#                     helpers.cpython-312.pyc
#                     helpers.cpython-313.pyc
#                     service.cpython-312.pyc
#                     service.cpython-313.pyc
#                     __init__.cpython-312.pyc
#                     __init__.cpython-313.pyc
#             flight/
#                 normalize.py
#                 service.py
#                 __init__.py
#                 adapters/
#                     api.py
#                     dataset.py
#                     __init__.py
#                     __pycache__/
#                         api.cpython-312.pyc
#                         api.cpython-313.pyc
#                         dataset.cpython-312.pyc
#                         dataset.cpython-313.pyc
#                         __init__.cpython-312.pyc
#                         __init__.cpython-313.pyc
#                 __pycache__/
#                     normalize.cpython-312.pyc
#                     normalize.cpython-313.pyc
#                     service.cpython-312.pyc
#                     service.cpython-313.pyc
#                     __init__.cpython-312.pyc
#                     __init__.cpython-313.pyc
#             hotel/
#                 normalize.py
#                 service.py
#                 __init__.py
#                 adapters/
#                     booking_api.py
#                     dataset.py
#                     ratings_api.py
#                     search_api.py
#                     __init__.py
#                     __pycache__/
#                         booking_api.cpython-312.pyc
#                         booking_api.cpython-313.pyc
#                         dataset.cpython-312.pyc
#                         dataset.cpython-313.pyc
#                         ratings_api.cpython-312.pyc
#                         ratings_api.cpython-313.pyc
#                         search_api.cpython-312.pyc
#                         search_api.cpython-313.pyc
#                         __init__.cpython-312.pyc
#                         __init__.cpython-313.pyc
#                 __pycache__/
#                     normalize.cpython-312.pyc
#                     normalize.cpython-313.pyc
#                     service.cpython-312.pyc
#                     service.cpython-313.pyc
#                     __init__.cpython-312.pyc
#                     __init__.cpython-313.pyc
#             places/
#                 normalize.py
#                 service.py
#                 __init__.py
#                 adapters/
#                     dataset.py
#                     google_api.py
#                     __init__.py
#                     __pycache__/
#                         google_api.cpython-312.pyc
#                         google_api.cpython-313.pyc
#                         __init__.cpython-312.pyc
#                         __init__.cpython-313.pyc
#                 __pycache__/
#                     normalize.cpython-312.pyc
#                     normalize.cpython-313.pyc
#                     service.cpython-312.pyc
#                     service.cpython-313.pyc
#                     __init__.cpython-312.pyc
#                     __init__.cpython-313.pyc
#             weather/
#                 normalize.py
#                 service.py
#                 __init__.py
#                 adapters/
#                     dataset.py
#                     openweather_api.py
#                     __init__.py
#                     __pycache__/
#                         openweather_api.cpython-312.pyc
#                         openweather_api.cpython-313.pyc
#                         __init__.cpython-312.pyc
#                         __init__.cpython-313.pyc
#                 __pycache__/
#                     normalize.cpython-312.pyc
#                     normalize.cpython-313.pyc
#                     service.cpython-312.pyc
#                     service.cpython-313.pyc
#                     __init__.cpython-312.pyc
#                     __init__.cpython-313.pyc
#         __pycache__/
#             api.cpython-312.pyc
#             api.cpython-313.pyc
#             composer_agent.cpython-312.pyc
#             composer_agent.cpython-313.pyc
#             local_tool_router.cpython-312.pyc
#             local_tool_router.cpython-313.pyc
#             planner_agent.cpython-312.pyc
#             planner_agent.cpython-313.pyc
#             travel_planner_graph.cpython-312.pyc
#             travel_planner_graph.cpython-313.pyc
#             __init__.cpython-312.pyc
#             __init__.cpython-313.pyc
#     langgraph_remote_agent/
#         agent_executor.py
#         booking_agent.py
#         __init__.py
#         __main__.py
#         __pycache__/
#             __init__.cpython-312.pyc
#             __main__.cpython-312.pyc
#     nlp/
#         flight_intent_extractor.py
#         hotel_intent_extractor.py
#         places_intent_extractor.py
#         __init__.py
#         __pycache__/
#             flight_intent_extractor.cpython-312.pyc
#             flight_intent_extractor.cpython-313.pyc
#             hotel_intent_extractor.cpython-312.pyc
#             hotel_intent_extractor.cpython-313.pyc
#             places_intent_extractor.cpython-312.pyc
#             places_intent_extractor.cpython-313.pyc
#             __init__.cpython-312.pyc
#             __init__.cpython-313.pyc
#     place_knowledge/
#         cache.py
#         client_factory.py
#         gpt_enricher.py
#         integration.py
#         orchestrator.py
#         quality_checker.py
#         schemas.py
#         wikipedia_fetcher.py
#         __init__.py
#         __pycache__/
#             cache.cpython-313.pyc
#             client_factory.cpython-313.pyc
#             gpt_enricher.cpython-313.pyc
#             integration.cpython-313.pyc
#             orchestrator.cpython-313.pyc
#             quality_checker.cpython-313.pyc
#             schemas.cpython-313.pyc
#             wikipedia_fetcher.cpython-313.pyc
#             __init__.cpython-313.pyc
#     postprocessing/
#         budget_enrichment.py
#         flight_enrichment.py
#         hotel_enrichment.py
#         itinerary_enrichment.py
#         places_enrichment.py
#         weather_enrichment.py
#         __init__.py
#         __pycache__/
#             budget_enrichment.cpython-312.pyc
#             budget_enrichment.cpython-313.pyc
#             flight_enrichment.cpython-312.pyc
#             flight_enrichment.cpython-313.pyc
#             hotel_enrichment.cpython-312.pyc
#             hotel_enrichment.cpython-313.pyc
#             itinerary_enrichment.cpython-312.pyc
#             itinerary_enrichment.cpython-313.pyc
#             places_enrichment.cpython-312.pyc
#             places_enrichment.cpython-313.pyc
#             weather_enrichment.cpython-312.pyc
#             weather_enrichment.cpython-313.pyc
#             __init__.cpython-312.pyc
#             __init__.cpython-313.pyc
#     shared/
#         client.py
#         mcp_client.py
#         schemas.py
#         server.py
#         test_mcp_client.py
#         __init__.py
#         __pycache__/
#             schemas.cpython-313.pyc
#             __init__.cpython-313.pyc
#     __pycache__/
#         __init__.cpython-312.pyc
#         __init__.cpython-313.pyc

# %%
import os, sys
import importlib
import pandas as pd

# 1) Ensure CWD is mlops root
if os.path.basename(os.getcwd()) == "notebook":
    os.chdir("..")
print("CWD:", os.getcwd())

# 2) Ensure mlops is importable (add backend/app to sys.path)
mlops_root = os.getcwd()                         # .../backend/app/mlops
backend_app_root = os.path.dirname(mlops_root)   # .../backend/app

if backend_app_root not in sys.path:
    sys.path.append(backend_app_root)

# 3) Import from mlops packages (NOT bare exception/utils)
from mlops.logging import setup_logging
from mlops.exception import dump_exception
from mlops.utils import db_utils

# 4) Optional: reload if you edit code often
importlib.reload(db_utils)

# 5) Setup logging once
setup_logging()

# %%
from utils.db_utils import read_sql_to_df
# Safe DB pulls
try:
    flights_df = read_sql_to_df("""
    SELECT
        origin,
        destination,
        airline,
        dep_time,
        arr_time,
        duration_minutes,
        price,
        travel_date,
        cabin_class
    FROM database_ml.flights;
""")
    print("Flights OK:", len(flights_df))
except Exception as e:
    dump_exception(
        e, 
        context={"table": "flights"}, 
        data_sample=pd.DataFrame()  # Empty for now
    )
    raise  # Still fail fast

# Repeat for hotels_df, cabs_df
try:
    hotels_df = read_sql_to_df("""
    SELECT
        hotel_name,
        city,
        rating,
        price_per_night,
        amenities,
        star_category
    FROM database_ml.hotels;
""")
    print("Hotels OK:", len(hotels_df))
except Exception as e:
    dump_exception(e, context={"table": "hotels"})
    raise

try:
    cabs_df = read_sql_to_df("""
    SELECT
        ride_date,
        ride_time,
        pickup_location,
        drop_location,
        vehicle_type,
        distance_km,
        price,
        payment_method,
        driver_rating,
        customer_rating,
        ride_status
    FROM database_ml.cabs;
""")
    print("Cabs OK:", len(cabs_df))
except Exception as e:
    dump_exception(e, context={"table": "cabs"})
    raise

# %%
print(flights_df.head())
print(hotels_df.head())
print(cabs_df.head())
