# %%
import os

# 1) Ensure we are in mlops
os.chdir(r"D:\labmentix\major\TravelGuru")

# 2) Walk and print tree
for root, dirs, files in os.walk("."):
    level = root.count(os.sep)
    indent = "    " * level
    print(f"{indent}{os.path.basename(root)}/")
    sub_indent = "    " * (level + 1)
    for f in files:
        print(f"{sub_indent}{f}")
# Out:
# ./
#     .gitignore
#     hello.py
#     pyproject.toml
#     README.md
#     requirements.txt
#     template.py
#     uv.lock
#     .git/
#         COMMIT_EDITMSG
#         config
#         description
#         FETCH_HEAD
#         HEAD
#         index
#         ORIG_HEAD
#         packed-refs
#         hooks/
#             applypatch-msg.sample
#             commit-msg.sample
#             fsmonitor-watchman.sample
#             post-update.sample
#             pre-applypatch.sample
#             pre-commit.sample
#             pre-merge-commit.sample
#             pre-push.sample
#             pre-rebase.sample
#             pre-receive.sample
#             prepare-commit-msg.sample
#             push-to-checkout.sample
#             sendemail-validate.sample
#             update.sample
#         info/
#             exclude
#         logs/
#             HEAD
#             refs/
#                 heads/
#                     main
#                     udit/
#                         mynewagent
#                         newagent
#                         readme
#                 remotes/
#                     origin/
#                         HEAD
#                         main
#                         Gayatri/
#                             My-New-Agent
#                         Tarang/
#                             agentic-AI
#                         udit/
#                             mynewagent
#                             newagent
#                             readme
#                         uttam/
#                             agentic_world
#                         uttam's/
#                             UV_cmd_macos_powershell
#         objects/
#             02/
#                 ae3067e687d580da137b43d24278aa02c40341
#             06/
#                 2061c5afe12e7a8890822182bf46d1e22eb3dd
#                 ceb8333c8eeae306ea3c41ff93897e404f7161
#             07/
#                 599ae9991402cef317a0f155cbff65fbd40e75
#                 88efa895799bfc6708356c80d8d762c21ae7c8
#             0a/
#                 abb77c47eee025d63c1654f93da92a2f286132
#             0c/
#                 91ed411c5c839061cd7efb822fe5ef312b3fd6
#             0d/
#                 6fac4d370f06726994c57ec51e68d90948d173
#             0f/
#                 cdae4ca506e1b82700327fa76909d4998e7a22
#                 f5cd0628d95db462e931780773247a4ae937ed
#             12/
#                 43506ae38a969592c80012042188d6ab98bafd
#                 914efe2d3dca240494ebda06fd1462f4037479
#                 f03e2cdddbb6aae00490f0461cb9e2df0f351d
#             15/
#                 6e373f0c0d2409de3c1169125443cda400c765
#             17/
#                 622f3340439f285f7b28a0bdf3dc957cc56dcf
#                 bd55706c47956ad4e1860b37c1d97c1bcf7133
#             18/
#                 b27665a46494ce65895b99ac21ba92aafb2d91
#                 e3dd1451938f585a91d8855daa1d5d54341e10
#             1b/
#                 6966efb918c811db7d5051a27c62e32aeceee3
#             1c/
#                 9317724c36fa5ee6773287bb5d6b2888280bca
#             1e/
#                 f81ad872621dc72eea1143990e9d5b6e341c63
#             20/
#                 9ef6510dac3cffa978df3bfad26bdb30584ef7
#                 f9f1a4a7c9a848e9625030b8e4fa4bce9d353e
#             21/
#                 3df3bcfa1a01126486f416a293d84216fc215b
#             22/
#                 a481a8e6d0fcc13e99f706ec5e2adab0e70a32
#             23/
#                 12f08acd6aa53a1c3ac93f219563046b8cda53
#                 fdc878f9975005818fa0d9d9107d4fc87bef09
#             e8/
#                 3617e1f9c8ba7071bdf24f4c832d994e22cdc8
#             ea/
#                 771b75b6b0b253a49072ced776f278747a16c0
#             eb/
#                 7e8d37c18782403252b62b03b746d729a7184b
#             f0/
#                 dc1779451c9dc119bd69b12cc678fe0ca80785
#             f1/
#                 958c6f388de9c59dbc64062f7732f7f3dce42d
#             f2/
#                 64fdba8acfca795d14bcdf2908baeedb1747a8
#             f4/
#                 65190113c07f303e669d89f1a05f7ad3db2ef7
#             f5/
#                 891a8c4d66ed0cc185a01b90814767c04b105c
#             f7/
#                 3822cb7bc6286007f8448e87ed0c86c108124e
#                 acb7ef09a4b24059a978d0f9ef43aa5928405c
#             f9/
#                 707bf0106c336fd2220ab36d84b249d050a901
#                 7998b2b7f730a8773e2f75cb8013ce7fc39ba4
#             fd/
#                 740df58c4c493f6cedbdccdb856afc780b6e16
#             info/
#             pack/
#                 pack-13cb94168ad37b658363ad93c2c43dd676bb629b.idx
#                 pack-13cb94168ad37b658363ad93c2c43dd676bb629b.pack
#                 pack-13cb94168ad37b658363ad93c2c43dd676bb629b.rev
#                 pack-b47251ee9474b93521d27b1bf938b84668275762.idx
#                 pack-b47251ee9474b93521d27b1bf938b84668275762.pack
#                 pack-b47251ee9474b93521d27b1bf938b84668275762.rev
#         refs/
#             heads/
#                 main
#                 udit/
#                     mynewagent
#                     newagent
#                     readme
#             remotes/
#                 origin/
#                     HEAD
#                     main
#                     Gayatri/
#                         My-New-Agent
#                     Tarang/
#                         agentic-AI
#                     udit/
#                         mynewagent
#                         newagent
#                         readme
#                     uttam/
#                         agentic_world
#                     uttam's/
#                         UV_cmd_macos_powershell
#             tags/
#     backend/
#         __init__.py
#         neo4j_database/
#             database_connection.py
#             __init__.py
#         travel_agent/
#             __init__.py
#     experiments/
#         notebook/
#             test.ipynb
#     mock_agent/
#         data.py
#         main.py
#         __pycache__/
#             data.cpython-312.pyc
#             main.cpython-312.pyc
#     readme_plans/
#         venky/
#             host_agent_&_remote_agent_plan.md
#             TravelGuru_Execution_Guide.md
#             TravelGuru_SaaS_Masterplan.md
#     travelguru-v5/
#         backend/
#             requirements.txt
#             app/
#                 main.py
#                 adapters/
#                     interceptors.py
#                     __init__.py
#                 agents/
#                     __init__.py
#                     adk_remote_agent/
#                         agent_executor.py
#                         budget_optimization_agent.py
#                         __init__.py
#                         __main__.py
#                     adk_travel_host/
#                         adk_tools.py
#                         remote_agent_connection.py
#                         travel_orchestrator_agent.py
#                         __init__.py
#                     crewai_remote_agent/
#                         agent_executor.py
#                         explorer_agent.py
#                         __init__.py
#                         __main__.py
#                     langgraph_remote_agent.py/
#                         agent_executor.py
#                         booking_agent.py
#                         __init__.py
#                         __main__.py
#                     shared/
#                         debug_a2a_methods.py
#                         mcp_client.py
#                         schemas.py
#                         test_mcp_client.py
#                         test_send_and_poll.py
#                         __init__.py
#                 api/
#                     v1/
#                         __init__.py
#                 clients/
#                     multi_client.py
#                 core/
#                     __init__.py
#                 db/
#                     models.py
#                     __init__.py
#                 frontend/
#                     app.py
#                 mcp/
#                     server.py
#                     __init__.py
#                 mlops/
#                     .env
#                     api.zip
#                     hotel_drift_report.html
#                     pipelines.zip
#                     test_evidently.py
#                     __init__.py
#                     adapters/
#                         agent_adapter.py
#                         real_agent_client.py
#                         __pycache__/
#                             agent_adapter.cpython-312.pyc
#                     api/
#                         main.py
#                         plan_trip.py
#                         schemas.py
#                         __init__.py
#                         __pycache__/
#                             main.cpython-312.pyc
#                             plan_trip.cpython-312.pyc
#                             schemas.cpython-312.pyc
#                             __init__.cpython-312.pyc
#                     artifacts/
#                         drift/
#                             hotel/
#                                 hotel_drift_report.html
#                     chatbot/
#                         orchestrator.py
#                         prompts.py
#                         state.py
#                     components/
#                         __init__.py
#                         evaluation/
#                             __init__.py
#                         monitoring/
#                             monitor.py
#                             __init__.py
#                             __pycache__/
#                                 monitor.cpython-312.pyc
#                                 __init__.cpython-312.pyc
#                         training/
#                             cab_trainer.py
#                             flight_trainer.py
#                             hotel_trainer.py
#                             trainer.py
#                             __init__.py
#                             artifacts/
#                                 cab_features.json
#                                 cab_preprocessor.pkl
#                                 cab_scoring.yaml
#                                 flight_features.json
#                                 flight_preprocessor.pkl
#                                 flight_scoring.yaml
#                                 hotel_features.json
#                                 hotel_preprocessor.pkl
#                                 hotel_scoring.yaml
#                         __pycache__/
#                             __init__.cpython-312.pyc
#                     contracts/
#                         agent_output.py
#                         agent_output_schema.py
#                         recommendation_response_schema.py
#                         trip_input_schema.py
#                         __pycache__/
#                             agent_output.cpython-312.pyc
#                             agent_output_schema.cpython-312.pyc
#                     exception/
#                         __init__.py
#                         __pycache__/
#                             __init__.cpython-312.pyc
#                     exceptions/
#                         error_20260115_195123_847.csv
#                     loggings/
#                         __init__.py
#                         __pycache__/
#                             __init__.cpython-312.pyc
#                     logs/
#                         mlops.log
#                     mlruns/
#                         .trash/
#                         0/
#                             meta.yaml
#                             087d41653bb34b57b54e5d970489a8ed/
#                                 meta.yaml
#                                 artifacts/
#                                 metrics/
#                                 params/
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                             08fd87a048a34f379a0532ba505722be/
#                                 meta.yaml
#                                 artifacts/
#                                 metrics/
#                                 params/
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                             2ee4d8c57416461cb8424b87a71c5625/
#                                 meta.yaml
#                                 artifacts/
#                                 metrics/
#                                 params/
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                             44480938c2cd42d2a52d490cae3f04e8/
#                                 meta.yaml
#                                 artifacts/
#                                 metrics/
#                                 params/
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                             4b450afbb4c34dc4b349ffbc0d91143e/
#                                 meta.yaml
#                                 artifacts/
#                                 metrics/
#                                 params/
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                             7136438b66f5463cb956630f5c52daed/
#                                 meta.yaml
#                                 artifacts/
#                                 metrics/
#                                 params/
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                             788d787801e94dc496cd884b0b4d99e2/
#                                 meta.yaml
#                                 artifacts/
#                                 metrics/
#                                 params/
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                             78ab74b9fb5d44798915aecf5cf15a25/
#                                 meta.yaml
#                                 artifacts/
#                                 metrics/
#                                 params/
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                             81a0feb1467144c6bf4c112927b6c1fe/
#                                 meta.yaml
#                                 artifacts/
#                                 metrics/
#                                 params/
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                             920bbd787f8f4e4f8b74ca7331b5beaa/
#                                 meta.yaml
#                                 artifacts/
#                                 metrics/
#                                 params/
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                             9cf911263c034520aa75bf3b058e1fe9/
#                                 meta.yaml
#                                 artifacts/
#                                 metrics/
#                                 params/
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                             a6c1199d30ab43f890be672d725fb602/
#                                 meta.yaml
#                                 artifacts/
#                                 metrics/
#                                 params/
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                             a7fe5a290e684e309f76d940c67d7c1a/
#                                 meta.yaml
#                                 artifacts/
#                                 metrics/
#                                 params/
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                             b3528894d678407a8c190236d3c3c1f4/
#                                 meta.yaml
#                                 artifacts/
#                                 metrics/
#                                 params/
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                             ccdd916efa0942c48f88dfd4b0c1b459/
#                                 meta.yaml
#                                 artifacts/
#                                 metrics/
#                                 params/
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                             e7f219ea095d4421be07cce0a819711b/
#                                 meta.yaml
#                                 artifacts/
#                                 metrics/
#                                 params/
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                         162806765193839091/
#                             meta.yaml
#                             054bfbf54cc44d14baad74dacc483d23/
#                                 meta.yaml
#                                 artifacts/
#                                     drift_reports/
#                                         hotel/
#                                             hotel_drift_report.html
#                                 metrics/
#                                 params/
#                                     entity
#                                     monitored_features
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.git.commit
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                             bcca18e28ded472db826d2f7e0467555/
#                                 meta.yaml
#                                 artifacts/
#                                     drift_reports/
#                                         hotel/
#                                             hotel_drift_report.html
#                                 metrics/
#                                 params/
#                                     entity
#                                     monitored_features
#                                 tags/
#                                     mlflow.runName
#                                     mlflow.source.git.commit
#                                     mlflow.source.name
#                                     mlflow.source.type
#                                     mlflow.user
#                             tags/
#                                 mlflow.experimentKind
#                         models/
#                     notebook/
#                         01_TravelGuru_EDA_FULL.ipynb
#                         02_TravelGuru_Feature_Engineering_FULL.ipynb
#                         superbase_pull_test.ipynb
#                         exceptions/
#                     pipelines/
#                         cab_ranking.py
#                         flight_ranking.py
#                         hotel_ranking.py
#                         pipelines.py
#                         __init__.py
#                         __pycache__/
#                             cab_ranking.cpython-312.pyc
#                             flight_ranking.cpython-312.pyc
#                             hotel_ranking.cpython-312.pyc
#                             pipelines.cpython-312.pyc
#                             __init__.cpython-312.pyc
#                     utils/
#                         db_utils.py
#                         __init__.py
#                         __pycache__/
#                             db_utils.cpython-312.pyc
#                             __init__.cpython-312.pyc
#                 services/
#                     __init__.py
#         data/
#             metadata/
#                 well-known-agents.json

# %%
import os, sys
import importlib
import pandas as pd

# 1) Ensure CWD is mlops root
if os.path.basename(os.getcwd()) == "notebook":
    os.chdir("..")
print("CWD:", os.getcwd())

# 2) Ensure mlops is importable (add backend/app to sys.path)
mlops_root = os.getcwd()                         # .../backend/app/mlops
backend_app_root = os.path.dirname(mlops_root)   # .../backend/app

if backend_app_root not in sys.path:
    sys.path.append(backend_app_root)

# 3) Import from mlops packages (NOT bare exception/utils)
from mlops.logging import setup_logging
from mlops.exception import dump_exception
from mlops.utils import db_utils

# 4) Optional: reload if you edit code often
importlib.reload(db_utils)

# 5) Setup logging once
setup_logging()
# Out:
# CWD: D:\labmentix\major\TravelGuru\travelguru-v5\backend\app\mlops

# %%
from utils.db_utils import read_sql_to_df
# Safe DB pulls
try:
    flights_df = read_sql_to_df("""
    SELECT
        origin,
        destination,
        airline,
        dep_time,
        arr_time,
        duration_minutes,
        price,
        travel_date,
        cabin_class
    FROM database_ml.flights;
""")
    print("Flights OK:", len(flights_df))
except Exception as e:
    dump_exception(
        e, 
        context={"table": "flights"}, 
        data_sample=pd.DataFrame()  # Empty for now
    )
    raise  # Still fail fast

# Repeat for hotels_df, cabs_df
try:
    hotels_df = read_sql_to_df("""
    SELECT
        hotel_name,
        city,
        rating,
        price_per_night,
        amenities,
        star_category
    FROM database_ml.hotels;
""")
    print("Hotels OK:", len(hotels_df))
except Exception as e:
    dump_exception(e, context={"table": "hotels"})
    raise

try:
    cabs_df = read_sql_to_df("""
    SELECT
        ride_date,
        ride_time,
        pickup_location,
        drop_location,
        vehicle_type,
        distance_km,
        price,
        payment_method,
        driver_rating,
        customer_rating,
        ride_status
    FROM database_ml.cabs;
""")
    print("Cabs OK:", len(cabs_df))
except Exception as e:
    dump_exception(e, context={"table": "cabs"})
    raise
# Out:
# 2026-01-15 20:23:34,526 utils.db_utils INFO Running query:
#     SELECT
#         origin,
#         destination,
#         airline,
#         dep_ti
# D:\labmentix\major\TravelGuru\travelguru-v5\backend\app\mlops\utils\db_utils.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn, params=params)
# 2026-01-15 20:23:37,089 utils.db_utils INFO Loaded 2906 rows
# Flights OK: 2906
# 2026-01-15 20:23:37,091 utils.db_utils INFO Running query:
#     SELECT
#         hotel_name,
#         city,
#         rating,
#         price_per_
# 2026-01-15 20:23:39,226 utils.db_utils INFO Loaded 1101 rows
# Hotels OK: 1101
# 2026-01-15 20:23:39,228 utils.db_utils INFO Running query:
#     SELECT
#         ride_date,
#         ride_time,
#         pickup_location,
#
# 2026-01-15 20:23:42,453 utils.db_utils INFO Loaded 33484 rows
# Cabs OK: 33484

# %%
print(flights_df.head())
print(hotels_df.head())
print(cabs_df.head())
# Out:
#   origin destination   airline            dep_time            arr_time  \
# 0    BOM         DEL   IndiGo  1900-01-01 08:30:00 1900-01-01 10:25:00
# 1    BOM         DEL   IndiGo  1900-01-01 07:45:00 1900-01-01 09:50:00
# 2    BOM         DEL  Vistara  1900-01-01 12:25:00 1900-01-01 14:30:00
# 3    BOM         DEL   IndiGo  1900-01-01 10:05:00 1900-01-01 12:15:00
# 4    BOM         DEL   IndiGo  1900-01-01 13:40:00 1900-01-01 15:50:00
#
#    duration_minutes   price travel_date cabin_class
# 0               115  6153.0  2022-02-14     Economy
# 1               125  5943.0  2022-02-14     Economy
# 2               125  6249.0  2022-02-14     Economy
# 3               130  5943.0  2022-02-14     Economy
# 4               130  5943.0  2022-02-14     Economy
#                 hotel_name   city  rating  price_per_night amenities  \
# 0       Crowne Plaza Kochi  kochi     4.6           8854.0      None
# 1     Trident Hotel Cochin  kochi     4.5           6441.0      None
# 2        The Galaxy Suites  kochi     3.8            831.0      None
# 3         The Renai cochin  kochi     4.2           2768.0      None
# 4  Ramada by Wyndham Kochi  kochi     4.5           8938.0      None
#
#    star_category
# 0              5
# 1              4
# 2              4
# 3              4
# 4              4
#     ride_date ride_time pickup_location drop_location vehicle_type  \
# 0  2024-01-28  06:00:00          Area-3        Area-2         Auto
# 1  2024-01-17  21:00:00         Area-38       Area-26  Prime Sedan
# 2  2024-01-30  00:00:00         Area-47        Area-8        eBike
# 3  2024-01-22  08:00:00         Area-11       Area-35    Prime SUV
# 4  2024-01-12  07:00:00         Area-43       Area-42  Prime Sedan
#
#    distance_km    price payment_method  driver_rating  customer_rating  \
# 0        28.50   868.06         Wallet            4.4              4.4
# 1        25.18   348.04           Card            4.5              4.7
# 2        17.67    56.33            UPI            3.6              3.3
# 3        24.94  1971.38            UPI            3.2              3.7
# 4        13.15  1130.15           Card            3.1              3.0
#
#   ride_status
# 0     Success
# 1     Success
# 2     Success
# 3     Success
# 4     Success
